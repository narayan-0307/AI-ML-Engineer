# %%
import matplotlib.pyplot as plt

# %%
X = [1, 2, 3, 4]
Y = [5, 6, 7, 8]

plt.plot(X, Y) # Line Plot
plt.show()

# %%
oscar_movies = {
    "movie_name": [
        "Silver Screen Dreams",
        "Golden Horizon",
        "Echoes of Time",
        "The Final Script",
        "Shadows & Light",
        "Broken Applause",
        "The Last Frame",
        "Whispering Stars",
        "Crown of Cinema",
        "Eternal Spotlight"
    ],
}

year = [2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023]
oscar_revenue = [120, 135, 150, 170, 165, 190, 180, 160, 200, 220]

plt.bar(year, oscar_revenue)

plt.title("Oscar Movies Revenue in Each Year")
plt.xlabel("Years")
plt.ylabel("Revenue (in $M)")
# Out:
# Text(0, 0.5, 'Revenue (in $M)')

# %%
non_oscar_movies = {
    "movie_name": [
        "City Lights Run",
        "Midnight Streets",
        "Neon Escape",
        "Chasing Thunder",
        "Lost Signal",
        "Final Countdown",
        "Shadow Protocol",
        "Broken Circuit",
        "Rising Voltage",
        "Last Horizon"
    ],
}

non_oscar_revenue = [80, 95, 110, 125, 130, 140, 135, 120, 150, 165]

# plt.plot(year, oscar_revenue, "o-.k" ,label="Oscae Movies")

# Sepetate making style
plt.plot(year, oscar_revenue, color="red", marker="*", linestyle="--", linewidth=1.5 ,label="Oscae Movies")

plt.plot(year, non_oscar_revenue, "*:m" ,label="Non-Oscar Movies")

plt.title("Oscal Movies Vs Non-Oscar Movies Revenue")
plt.xlabel("Years")
plt.ylabel("Revenue (in $M)")

plt.legend()
plt.legend(loc="upper right") # Using the Loc() can set location wherever we want to show this.

# %%
non_oscar_movies = [
        "City Lights Run",
        "Midnight Streets",
        "Neon Escape",
        "Chasing Thunder",
        "Lost Signal",
        "Final Countdown",
        "Shadow Protocol",
        "Broken Circuit",
        "Rising Voltage",
        "Last Horizon"
]

non_oscar_revenue = [80, 95, 110, 125, 130, 140, 135, 120, 150, 165]

plt.plot(year, oscar_revenue, label="Oscae Movies")

plt.plot(year, non_oscar_revenue, "*:m" ,label="Non-Oscar Movies")

plt.title("Oscal Movies Vs Non-Oscar Movies Revenue")
plt.xlabel("Years")
plt.ylabel("Revenue (in $M)")

plt.legend()

# style.available
plt.style.available # Get all styles

# style.use()
plt.style.use("classic")

plt.grid()

plt.show()

# Using the xkcd - cartoonish graph
# with plt.xkcd:
#     plt.plot(year, oscar_revenue, label="Oscae Movies")

#     plt.plot(year, non_oscar_revenue, "*:m" ,label="Non-Oscar Movies")
    
#     plt.title("Oscal Movies Vs Non-Oscar Movies Revenue")
#     plt.xlabel("Years")
#     plt.ylabel("Revenue (in $M)")
    
#     plt.legend()
    

    
#     plt.show()

# %%
oscar_movies = [
        "Silver Screen Dreams",
        "Golden Horizon",
        "Echoes of Time",
        "The Final Script",
        "Shadows & Light",
        "Broken Applause",
        "The Last Frame",
        "Whispering Stars",
        "Crown of Cinema",
        "Eternal Spotlight"
]

year = [2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023]
oscar_revenue = [120, 135, 150, 170, 165, 190, 180, 160, 200, 220]

plt.plot(oscar_movies, year)

plt.style.use("default")
plt.title("Oscar Movies Revenue in Each Year")
plt.xlabel("Years")
plt.ylabel("Revenue (in $M)")

plt.tight_layout()

plt.savefig("final_output.png")

# %% [markdown]
# # Bar Charts -

# %%
movies = [
        "Silver Screen Dreams",
        "Golden Horizon",
        "Echoes of Time",
        "The Final Script",
        "Shadows & Light",
        "Broken Applause",
        "The Last Frame",
        "Whispering Stars",
        "Crown of Cinema",
        "Eternal Spotlight"
]

year = [2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023]
revenue = [120, 135, 150, 170, 165, 190, 180, 160, 200, 220]

plt.bar(year, revenue)
plt.title("Revenue in each Year for oscar movies")
plt.xlabel("Years")
plt.ylabel("Revenue (in $M)")

plt.text(year[0], revenue[0] + 5, revenue[0], ha="center")

for i in range(len(year)):
    plt.text(year[i], revenue[i] + 5, revenue[i], ha="center")

plt.ylim(0, max(revenue) + 20)

plt.xlim(min(year), max(year) + 1)
# Out:
# (2014.0, 2024.0)

# %%
import numpy as np

oscar_movies = [
        "Silver Screen Dreams",
        "Golden Horizon",
        "Echoes of Time",
        "The Final Script",
        "Shadows & Light",
        "Broken Applause",
        "The Last Frame",
        "Whispering Stars",
        "Crown of Cinema",
        "Eternal Spotlight"
]
oscar_revenue = [120, 135, 150, 170, 165, 190, 180, 160, 200, 220]


non_oscar_movies =[
        "City Lights Run",
        "Midnight Streets",
        "Neon Escape",
        "Chasing Thunder",
        "Lost Signal",
        "Final Countdown",
        "Shadow Protocol",
        "Broken Circuit",
        "Rising Voltage",
        "Last Horizon"
]
non_oscar_revenue = [80, 95, 110, 125, 130, 140, 135, 120, 150, 165]

years = [2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023]

x = np.arange(len(years))



# --- 2 Set of graph ---
width = 0.4
plt.bar(x-width/2, oscar_revenue, width, label="Oscar Movies")
plt.bar(x+width/2, non_oscar_revenue, width, label="Non-Oscar Movies")

# --- 3 Set of graph ---
# width = 0.25
# plt.bar(x-width, oscar_revenue, width, label="Oscar Movies")
# plt.bar(x, non_oscar_revenue, width, label="Non-Oscar Movies")
# plt.bar(x+width, non_oscar_revenue, width, label="2 Non-Oscar Movies")

# plt.bar(years, oscar_revenue)
# plt.bar(years, non_oscar_revenue)

plt.title("Oscal Vs Non-Oscar Movies Revenue")
plt.xlabel("Years")
plt.ylabel("Revenue ($M)")
plt.legend()

# xticks ---> replace the y labels value
plt.xticks(x, years)


plt.show()

# %% [markdown]
# # HORIZONTAL GRAPH

# %%
non_oscar_movies =[
        "City Lights Run",
        "Midnight Streets",
        "Neon Escape",
        "Chasing Thunder",
        "Lost Signal",
        "Final Countdown",
        "Shadow Protocol",
        "Broken Circuit",
        "Rising Voltage",
        "Last Horizon"
]
non_oscar_revenue = [80, 95, 110, 125, 130, 140, 135, 120, 150, 165]

plt.barh(non_oscar_movies, non_oscar_revenue)
plt.ylabel("Movies")
plt.xlabel("Revenue")

plt.show()

# %% [markdown]
# # SCATTER PLOT

# %%
people =["PersonA", "PersonB", "PersonC", "PersonD", "PersonE", "PersonF", "PersonG", "PersonH", 
                   "PersonI", "PersonJ"]
age = [22, 25, 30, 35, 40, 45, 50, 55, 60, 65]
blood_pressure = [110, 115, 120, 122, 125, 130, 135, 123, 145, 150]

# colors = ["green" if x < 135 else "red" for x in blood_pressure]
# plt.scatter(age, blood_pressure, color=colors)


# plt.scatter(age, blood_pressure, color="green", s=blood_pressure, marker="o", alpha=0.7)
plt.scatter(age, blood_pressure, s=blood_pressure, cmap="YlGn", c=blood_pressure)
plt.title("Age Vs Blood Pressure")
plt.xlabel("Age")
plt.ylabel("Blood Pressure")

plt.grid()
plt.colorbar(label="BP")

for i in range(len(people)):
    plt.annotate(
        people[i], 
        xy=(age[i], blood_pressure[i]), 
        xytext=(age[i] + 1, blood_pressure[i] + 1)
)

plt.xlim(min(age), max(age) + 10)
plt.ylim(min(blood_pressure), max(blood_pressure) + 5)

plt.show()

# %% [markdown]
# # Multiple DataSet

# %%
cities = ["City A", "City B", "City C", "City D", "City E"]

# Winter: Tempreture (C) Vs Humidity (%)
winter_temp = [5, 2, 10, 0, 7]
winter_humidity = [80, 75, 65, 85, 70]

# Summer: Temperature (C) & Humidity (%)
summer_temp = [25, 30, 28, 35, 27]
summer_humidity = [60, 50, 55, 45, 65]

plt.scatter(winter_temp, winter_humidity, label="Winter")
plt.scatter(summer_temp, summer_humidity, label="Summer")

plt.title("Summer Vs Winter Data")
plt.xlabel("Tempareture (c)")
plt.ylabel("Humidity (%)")

plt.legend()

# %% [markdown]
# # Pie Chart

# %%
expenses = ["Salaries", "Rent", "Marketing", "R&D", "Miscellaneous"]
amounts = [500, 150, 120, 100, 50]

# plt.style.use("dark_background")
# plt.pie(amounts, labels=expenses, autopct="%1.1f%%") # autopct --> Get the % of each slice

# colors = ["red", "green", "yellow", "pink", "purple"]
# plt.pie(amounts, labels=expenses, autopct="%1.1f%%", colors=colors) # Add the colors of each slice

explode = [0, 0.4, 0, 0.2, 0]

plt.pie(amounts, labels=expenses, autopct="%1.1f%%",
    wedgeprops = {
        "edgecolor": "black",
        "linewidth": 1.5,
        "linestyle": "--",
        # "alpha": 0.4,
        # "fill": False
    },
    explode = explode,
    startangle = 90, # 90 means the 90 degree
    shadow= True # Add shadow like 3D
)

# plt.style.available

plt.show()
